# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import tensorflow as tf
import pandas as pd
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
df = pd.read_csv('dataset_info_parts.csv')
PATH_data = 'dataset/'
IMG_RESIZE_PATH_data = PATH_data+'images_resize/'
IMG_SIZE = (360,468)
BATCH_SIZE = 16
df['file_path'] = IMG_RESIZE_PATH_data + df['file']+'.jpg'
animals = ['sheep', 'dog', 'cow', 'cat', 'horse'] #{'horse': 0, 'cow': 1}

# %%
datagen = ImageDataGenerator(horizontal_flip=True, rotation_range=10)#rescale=1./255)
train_ds = datagen.flow_from_dataframe(df[df['split']=='train'], x_col='file_path', y_col='cat', class_mode='categorical',
                                       target_size=(IMG_SIZE[0],IMG_SIZE[1]),batch_size=BATCH_SIZE, classes=animals)
val_ds = datagen.flow_from_dataframe(df[df['split']=='val'], x_col='file_path', y_col='cat', class_mode='categorical',
                                     target_size=(IMG_SIZE[0],IMG_SIZE[1]),batch_size=BATCH_SIZE, classes=animals)
# Out:
# Found 375 validated image filenames belonging to 5 classes.
# Found 162 validated image filenames belonging to 5 classes.

# %%
IMG_SHAPE = IMG_SIZE + (3,)
inputs = tf.keras.Input(shape=IMG_SHAPE)
input_pre = tf.keras.applications.vgg16.preprocess_input(inputs)
base_model = tf.keras.applications.VGG16(input_tensor=input_pre, include_top=False, weights=None)
base_model.trainable=True

x = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
x = tf.keras.layers.Dense(256, activation='relu')(x)
x = tf.keras.layers.Dense(128, activation='relu')(x)
outputs = tf.keras.layers.Dense(len(animals), activation='softmax')(x)
model = tf.keras.Model(inputs, outputs)

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 360, 468, 3)]     0
#
#  tf.__operators__.getitem (S  (None, 360, 468, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 360, 468, 3)      0
#
#  block1_conv1 (Conv2D)       (None, 360, 468, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 360, 468, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 180, 234, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 180, 234, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 180, 234, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 90, 117, 128)      0
#
#  block3_conv1 (Conv2D)       (None, 90, 117, 256)      295168
#
#  block3_conv2 (Conv2D)       (None, 90, 117, 256)      590080
#
#  block3_conv3 (Conv2D)       (None, 90, 117, 256)      590080
#
#  block3_pool (MaxPooling2D)  (None, 45, 58, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 45, 58, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 45, 58, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 45, 58, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 22, 29, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 22, 29, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 22, 29, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 22, 29, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 11, 14, 512)       0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               131328
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  dense_2 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 14,879,557
# Trainable params: 14,879,557
# Non-trainable params: 0
# _________________________________________________________________

# %%
#lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=0.0001, decay_steps=10000,decay_rate=0.9)
EPOCHS = 150
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),loss=tf.keras.losses.CategoricalCrossentropy(),metrics=['accuracy'])
history = model.fit(train_ds,epochs=EPOCHS,validation_data=val_ds)
df_history =pd.DataFrame(history.history)
# Out:
# Epoch 1/150
# 24/24 [==============================] - 106s 4s/step - loss: 1.6106 - accuracy: 0.2453 - val_loss: 1.6075 - val_accuracy: 0.2346
# Epoch 2/150
# 24/24 [==============================] - 55s 2s/step - loss: 1.6045 - accuracy: 0.2187 - val_loss: 1.6011 - val_accuracy: 0.2346
# Epoch 3/150
# 24/24 [==============================] - 51s 2s/step - loss: 1.6055 - accuracy: 0.2080 - val_loss: 1.6001 - val_accuracy: 0.2346
# Epoch 4/150
# 24/24 [==============================] - 55s 2s/step - loss: 1.5985 - accuracy: 0.2320 - val_loss: 1.5986 - val_accuracy: 0.2346
# Epoch 5/150
# 24/24 [==============================] - 55s 2s/step - loss: 1.5723 - accuracy: 0.2320 - val_loss: 1.5571 - val_accuracy: 0.2407
# Epoch 6/150
# 24/24 [==============================] - 55s 2s/step - loss: 1.5820 - accuracy: 0.2240 - val_loss: 1.5997 - val_accuracy: 0.2593
# Epoch 7/150
# 24/24 [==============================] - 54s 2s/step - loss: 1.5755 - accuracy: 0.2373 - val_loss: 1.5663 - val_accuracy: 0.2469
# Epoch 8/150
# 24/24 [==============================] - 54s 2s/step - loss: 1.5961 - accuracy: 0.2453 - val_loss: 1.5890 - val_accuracy: 0.2469
# Epoch 9/150
# 24/24 [==============================] - 55s 2s/step - loss: 1.5988 - accuracy: 0.2160 - val_loss: 1.5952 - val_accuracy: 0.2284
# Epoch 10/150
# 24/24 [==============================] - 43s 2s/step - loss: 1.5748 - accuracy: 0.1893 - val_loss: 1.5651 - val_accuracy: 0.2284
# Epoch 11/150
# 24/24 [==============================] - 45s 2s/step - loss: 1.5493 - accuracy: 0.2293 - val_loss: 1.5451 - val_accuracy: 0.2901
# Epoch 12/150
# 24/24 [==============================] - 52s 2s/step - loss: 1.5138 - accuracy: 0.2773 - val_loss: 1.9475 - val_accuracy: 0.3086
# Epoch 13/150
# 24/24 [==============================] - 58s 2s/step - loss: 1.5382 - accuracy: 0.2480 - val_loss: 1.5496 - val_accuracy: 0.2901
# Epoch 14/150
# 24/24 [==============================] - 58s 2s/step - loss: 1.5100 - accuracy: 0.2933 - val_loss: 1.5976 - val_accuracy: 0.3210
# Epoch 15/150
# 24/24 [==============================] - 58s 2s/step - loss: 1.5282 - accuracy: 0.2827 - val_loss: 1.5520 - val_accuracy: 0.3086
# Epoch 16/150
# 24/24 [==============================] - 59s 2s/step - loss: 1.4744 - accuracy: 0.3120 - val_loss: 1.5835 - val_accuracy: 0.2593
# Epoch 17/150
# 24/24 [==============================] - 59s 2s/step - loss: 1.5158 - accuracy: 0.2453 - val_loss: 1.5636 - val_accuracy: 0.3457
# Epoch 18/150
# 24/24 [==============================] - 59s 2s/step - loss: 1.5118 - accuracy: 0.2667 - val_loss: 1.5471 - val_accuracy: 0.2840
# Epoch 19/150
# 24/24 [==============================] - 59s 2s/step - loss: 1.4883 - accuracy: 0.2880 - val_loss: 1.5044 - val_accuracy: 0.3148
# Epoch 20/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.4411 - accuracy: 0.3200 - val_loss: 1.5043 - val_accuracy: 0.2840
# Epoch 21/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.4669 - accuracy: 0.3093 - val_loss: 1.6541 - val_accuracy: 0.3210
# Epoch 22/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.4963 - accuracy: 0.3360 - val_loss: 1.5546 - val_accuracy: 0.3148
# Epoch 23/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.4753 - accuracy: 0.3040 - val_loss: 1.5104 - val_accuracy: 0.2407
# Epoch 24/150
# 24/24 [==============================] - 58s 2s/step - loss: 1.4541 - accuracy: 0.2987 - val_loss: 1.4890 - val_accuracy: 0.3148
# Epoch 25/150
# 24/24 [==============================] - 58s 2s/step - loss: 1.4296 - accuracy: 0.3280 - val_loss: 1.5241 - val_accuracy: 0.3457
# Epoch 26/150
# 24/24 [==============================] - 58s 2s/step - loss: 1.4123 - accuracy: 0.3147 - val_loss: 1.5153 - val_accuracy: 0.3272
# Epoch 27/150
# 24/24 [==============================] - 58s 2s/step - loss: 1.4325 - accuracy: 0.3440 - val_loss: 1.4839 - val_accuracy: 0.3148
# Epoch 28/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.4127 - accuracy: 0.3200 - val_loss: 1.5285 - val_accuracy: 0.2531
# Epoch 29/150
# 24/24 [==============================] - 58s 2s/step - loss: 1.3831 - accuracy: 0.3493 - val_loss: 1.4880 - val_accuracy: 0.3210
# Epoch 30/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.4024 - accuracy: 0.3520 - val_loss: 1.5077 - val_accuracy: 0.3519
# Epoch 31/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.4292 - accuracy: 0.3253 - val_loss: 1.5073 - val_accuracy: 0.2963
# Epoch 32/150
# 24/24 [==============================] - 58s 2s/step - loss: 1.4024 - accuracy: 0.3467 - val_loss: 1.5129 - val_accuracy: 0.2901
# Epoch 33/150
# 24/24 [==============================] - 59s 2s/step - loss: 1.3668 - accuracy: 0.3547 - val_loss: 1.5543 - val_accuracy: 0.2963
# Epoch 34/150
# 24/24 [==============================] - 59s 2s/step - loss: 1.3763 - accuracy: 0.3467 - val_loss: 1.5617 - val_accuracy: 0.2840
# Epoch 35/150
# 24/24 [==============================] - 60s 2s/step - loss: 1.3752 - accuracy: 0.3467 - val_loss: 1.4662 - val_accuracy: 0.3025
# Epoch 36/150
# 24/24 [==============================] - 58s 2s/step - loss: 1.3617 - accuracy: 0.3893 - val_loss: 1.4949 - val_accuracy: 0.3519
# Epoch 37/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.3306 - accuracy: 0.3760 - val_loss: 1.4799 - val_accuracy: 0.3457
# Epoch 38/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.3490 - accuracy: 0.3733 - val_loss: 1.4867 - val_accuracy: 0.3765
# Epoch 39/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.3224 - accuracy: 0.3973 - val_loss: 1.4946 - val_accuracy: 0.3580
# Epoch 40/150
# 24/24 [==============================] - 56s 2s/step - loss: 1.3255 - accuracy: 0.4373 - val_loss: 1.4979 - val_accuracy: 0.3272
# Epoch 41/150
# 24/24 [==============================] - 56s 2s/step - loss: 1.3269 - accuracy: 0.3973 - val_loss: 1.4475 - val_accuracy: 0.3580
# Epoch 42/150
# 24/24 [==============================] - 56s 2s/step - loss: 1.3568 - accuracy: 0.4240 - val_loss: 1.4842 - val_accuracy: 0.3272
# Epoch 43/150
# 24/24 [==============================] - 56s 2s/step - loss: 1.2836 - accuracy: 0.4293 - val_loss: 1.4689 - val_accuracy: 0.3457
# Epoch 44/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.2660 - accuracy: 0.4453 - val_loss: 1.6952 - val_accuracy: 0.3642
# Epoch 45/150
# 24/24 [==============================] - 53s 2s/step - loss: 1.3089 - accuracy: 0.4347 - val_loss: 1.4871 - val_accuracy: 0.3210
# Epoch 46/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.2587 - accuracy: 0.4347 - val_loss: 1.4695 - val_accuracy: 0.3704
# Epoch 47/150
# 24/24 [==============================] - 58s 2s/step - loss: 1.2419 - accuracy: 0.4773 - val_loss: 1.5376 - val_accuracy: 0.3704
# Epoch 48/150
# 24/24 [==============================] - 58s 2s/step - loss: 1.2634 - accuracy: 0.4613 - val_loss: 1.5001 - val_accuracy: 0.3210
# Epoch 49/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.2356 - accuracy: 0.4533 - val_loss: 1.5660 - val_accuracy: 0.3827
# Epoch 50/150
# 24/24 [==============================] - 56s 2s/step - loss: 1.2944 - accuracy: 0.4213 - val_loss: 1.4541 - val_accuracy: 0.3457
# Epoch 51/150
# 24/24 [==============================] - 58s 2s/step - loss: 1.2407 - accuracy: 0.4560 - val_loss: 1.5915 - val_accuracy: 0.3148
# Epoch 52/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.1809 - accuracy: 0.4827 - val_loss: 1.5269 - val_accuracy: 0.3395
# Epoch 53/150
# 24/24 [==============================] - 56s 2s/step - loss: 1.1672 - accuracy: 0.4720 - val_loss: 1.7267 - val_accuracy: 0.3148
# Epoch 54/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.1879 - accuracy: 0.4773 - val_loss: 1.6104 - val_accuracy: 0.3333
# Epoch 55/150
# 24/24 [==============================] - 53s 2s/step - loss: 1.1484 - accuracy: 0.5200 - val_loss: 1.6102 - val_accuracy: 0.3704
# Epoch 56/150
# 24/24 [==============================] - 48s 2s/step - loss: 1.0786 - accuracy: 0.5333 - val_loss: 1.5546 - val_accuracy: 0.3519
# Epoch 57/150
# 24/24 [==============================] - 55s 2s/step - loss: 1.0888 - accuracy: 0.5173 - val_loss: 1.6181 - val_accuracy: 0.3642
# Epoch 58/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.0729 - accuracy: 0.5413 - val_loss: 1.7912 - val_accuracy: 0.3642
# Epoch 59/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.1999 - accuracy: 0.4907 - val_loss: 1.4901 - val_accuracy: 0.3580
# Epoch 60/150
# 24/24 [==============================] - 58s 2s/step - loss: 1.1005 - accuracy: 0.5280 - val_loss: 1.7693 - val_accuracy: 0.3148
# Epoch 61/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.0661 - accuracy: 0.5520 - val_loss: 1.5394 - val_accuracy: 0.3642
# Epoch 62/150
# 24/24 [==============================] - 57s 2s/step - loss: 1.0538 - accuracy: 0.5253 - val_loss: 1.5974 - val_accuracy: 0.3889
# Epoch 63/150
# 24/24 [==============================] - 55s 2s/step - loss: 1.0404 - accuracy: 0.5653 - val_loss: 1.6934 - val_accuracy: 0.3210
# Epoch 64/150
# 24/24 [==============================] - 41s 2s/step - loss: 1.0628 - accuracy: 0.5227 - val_loss: 1.8282 - val_accuracy: 0.3333
# Epoch 65/150
# 24/24 [==============================] - 54s 2s/step - loss: 1.1073 - accuracy: 0.5120 - val_loss: 1.7235 - val_accuracy: 0.3951
# Epoch 66/150
# 24/24 [==============================] - 57s 2s/step - loss: 0.9701 - accuracy: 0.5573 - val_loss: 1.8828 - val_accuracy: 0.3025
# Epoch 67/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.9199 - accuracy: 0.6053 - val_loss: 1.9822 - val_accuracy: 0.3765
# Epoch 68/150
# 24/24 [==============================] - 58s 2s/step - loss: 0.9397 - accuracy: 0.5653 - val_loss: 1.9964 - val_accuracy: 0.3951
# Epoch 69/150
# 24/24 [==============================] - 56s 2s/step - loss: 0.8572 - accuracy: 0.6347 - val_loss: 2.0645 - val_accuracy: 0.3827
# Epoch 70/150
# 24/24 [==============================] - 56s 2s/step - loss: 0.9632 - accuracy: 0.5947 - val_loss: 1.7847 - val_accuracy: 0.3889
# Epoch 71/150
# 24/24 [==============================] - 56s 2s/step - loss: 0.8517 - accuracy: 0.6373 - val_loss: 2.2538 - val_accuracy: 0.3519
# Epoch 72/150
# 24/24 [==============================] - 56s 2s/step - loss: 0.9456 - accuracy: 0.5973 - val_loss: 1.7505 - val_accuracy: 0.3395
# Epoch 73/150
# 24/24 [==============================] - 57s 2s/step - loss: 0.8864 - accuracy: 0.6347 - val_loss: 2.1350 - val_accuracy: 0.3704
# Epoch 74/150
# 24/24 [==============================] - 57s 2s/step - loss: 0.9182 - accuracy: 0.6480 - val_loss: 1.6926 - val_accuracy: 0.3395
# Epoch 75/150
# 24/24 [==============================] - 57s 2s/step - loss: 0.7861 - accuracy: 0.6853 - val_loss: 2.3196 - val_accuracy: 0.3951
# Epoch 76/150
# 24/24 [==============================] - 56s 2s/step - loss: 1.1539 - accuracy: 0.5067 - val_loss: 1.5887 - val_accuracy: 0.3025
# Epoch 77/150
# 24/24 [==============================] - 58s 2s/step - loss: 1.0004 - accuracy: 0.5547 - val_loss: 1.9687 - val_accuracy: 0.4074
# Epoch 78/150
# 24/24 [==============================] - 55s 2s/step - loss: 0.8328 - accuracy: 0.6640 - val_loss: 2.0568 - val_accuracy: 0.3951
# Epoch 79/150
# 24/24 [==============================] - 56s 2s/step - loss: 0.6939 - accuracy: 0.7040 - val_loss: 2.2900 - val_accuracy: 0.3642
# Epoch 80/150
# 24/24 [==============================] - 56s 2s/step - loss: 0.7059 - accuracy: 0.6907 - val_loss: 2.6490 - val_accuracy: 0.3025
# Epoch 81/150
# 24/24 [==============================] - 56s 2s/step - loss: 0.7297 - accuracy: 0.6933 - val_loss: 2.4750 - val_accuracy: 0.3765
# Epoch 82/150
# 24/24 [==============================] - 58s 2s/step - loss: 0.7956 - accuracy: 0.6507 - val_loss: 2.0615 - val_accuracy: 0.4136
# Epoch 83/150
# 24/24 [==============================] - 57s 2s/step - loss: 0.7542 - accuracy: 0.6933 - val_loss: 2.4197 - val_accuracy: 0.4074
# Epoch 84/150
# 24/24 [==============================] - 57s 2s/step - loss: 0.6854 - accuracy: 0.7440 - val_loss: 2.1986 - val_accuracy: 0.4012
# Epoch 85/150
# 24/24 [==============================] - 57s 2s/step - loss: 0.5907 - accuracy: 0.7520 - val_loss: 2.4254 - val_accuracy: 0.4012
# Epoch 86/150
# 24/24 [==============================] - 57s 2s/step - loss: 0.6807 - accuracy: 0.7467 - val_loss: 2.2653 - val_accuracy: 0.3642
# Epoch 87/150
# 24/24 [==============================] - 56s 2s/step - loss: 0.7635 - accuracy: 0.7040 - val_loss: 2.1775 - val_accuracy: 0.3519
# Epoch 88/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.5557 - accuracy: 0.7760 - val_loss: 3.0004 - val_accuracy: 0.3951
# Epoch 89/150
# 24/24 [==============================] - 56s 2s/step - loss: 0.5634 - accuracy: 0.7840 - val_loss: 2.7821 - val_accuracy: 0.3642
# Epoch 90/150
# 24/24 [==============================] - 57s 2s/step - loss: 0.6038 - accuracy: 0.7680 - val_loss: 2.7133 - val_accuracy: 0.3580
# Epoch 91/150
# 24/24 [==============================] - 57s 2s/step - loss: 0.6223 - accuracy: 0.7307 - val_loss: 2.5092 - val_accuracy: 0.3827
# Epoch 92/150
# 24/24 [==============================] - 56s 2s/step - loss: 0.5083 - accuracy: 0.8080 - val_loss: 3.3163 - val_accuracy: 0.4321
# Epoch 93/150
# 24/24 [==============================] - 56s 2s/step - loss: 0.5598 - accuracy: 0.7867 - val_loss: 2.7098 - val_accuracy: 0.3642
# Epoch 94/150
# 24/24 [==============================] - 56s 2s/step - loss: 0.5470 - accuracy: 0.7733 - val_loss: 3.3250 - val_accuracy: 0.3395
# Epoch 95/150
# 24/24 [==============================] - 57s 2s/step - loss: 0.4783 - accuracy: 0.8240 - val_loss: 3.5634 - val_accuracy: 0.3704
# Epoch 96/150
# 24/24 [==============================] - 57s 2s/step - loss: 0.4636 - accuracy: 0.8107 - val_loss: 3.9027 - val_accuracy: 0.3951
# Epoch 97/150
# 24/24 [==============================] - 56s 2s/step - loss: 0.5131 - accuracy: 0.8080 - val_loss: 3.0091 - val_accuracy: 0.4136
# Epoch 98/150
# 24/24 [==============================] - 57s 2s/step - loss: 0.5194 - accuracy: 0.8000 - val_loss: 2.9446 - val_accuracy: 0.3704
# Epoch 99/150
# 24/24 [==============================] - 56s 2s/step - loss: 0.4802 - accuracy: 0.8080 - val_loss: 3.2687 - val_accuracy: 0.3827
# Epoch 100/150
# 24/24 [==============================] - 57s 2s/step - loss: 0.4183 - accuracy: 0.8427 - val_loss: 3.4890 - val_accuracy: 0.4074
# Epoch 101/150
# 24/24 [==============================] - 56s 2s/step - loss: 0.3891 - accuracy: 0.8453 - val_loss: 3.4169 - val_accuracy: 0.3889
# Epoch 102/150
# 24/24 [==============================] - 57s 2s/step - loss: 0.3218 - accuracy: 0.8747 - val_loss: 4.1921 - val_accuracy: 0.3765
# Epoch 103/150
# 24/24 [==============================] - 57s 2s/step - loss: 0.3637 - accuracy: 0.8507 - val_loss: 4.6017 - val_accuracy: 0.3642
# Epoch 104/150
# 24/24 [==============================] - 56s 2s/step - loss: 0.5251 - accuracy: 0.7947 - val_loss: 3.0315 - val_accuracy: 0.3642
# Epoch 105/150
# 24/24 [==============================] - 58s 2s/step - loss: 0.3697 - accuracy: 0.8587 - val_loss: 3.4628 - val_accuracy: 0.3765
# Epoch 106/150
# 24/24 [==============================] - 62s 3s/step - loss: 0.2771 - accuracy: 0.8880 - val_loss: 4.0757 - val_accuracy: 0.4136
# Epoch 107/150
# 24/24 [==============================] - 61s 3s/step - loss: 0.2680 - accuracy: 0.8800 - val_loss: 4.3989 - val_accuracy: 0.3889
# Epoch 108/150
# 24/24 [==============================] - 62s 3s/step - loss: 0.1944 - accuracy: 0.9253 - val_loss: 4.6580 - val_accuracy: 0.4074
# Epoch 109/150
# 24/24 [==============================] - 62s 3s/step - loss: 0.1654 - accuracy: 0.9360 - val_loss: 6.5450 - val_accuracy: 0.3765
# Epoch 110/150
# 24/24 [==============================] - 62s 3s/step - loss: 0.6156 - accuracy: 0.8027 - val_loss: 2.6157 - val_accuracy: 0.4136
# Epoch 111/150
# 24/24 [==============================] - 60s 2s/step - loss: 0.6563 - accuracy: 0.7840 - val_loss: 2.5744 - val_accuracy: 0.3889
# Epoch 112/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.3117 - accuracy: 0.9013 - val_loss: 3.4936 - val_accuracy: 0.4568
# Epoch 113/150
# 24/24 [==============================] - 61s 3s/step - loss: 0.2276 - accuracy: 0.9067 - val_loss: 4.5087 - val_accuracy: 0.3457
# Epoch 114/150
# 24/24 [==============================] - 61s 3s/step - loss: 0.1948 - accuracy: 0.9333 - val_loss: 4.6862 - val_accuracy: 0.3580
# Epoch 115/150
# 24/24 [==============================] - 60s 3s/step - loss: 0.1659 - accuracy: 0.9467 - val_loss: 5.1609 - val_accuracy: 0.3827
# Epoch 116/150
# 24/24 [==============================] - 61s 3s/step - loss: 0.2752 - accuracy: 0.9253 - val_loss: 4.0033 - val_accuracy: 0.4136
# Epoch 117/150
# 24/24 [==============================] - 60s 3s/step - loss: 0.1896 - accuracy: 0.9333 - val_loss: 4.8986 - val_accuracy: 0.4198
# Epoch 118/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.2605 - accuracy: 0.9093 - val_loss: 4.0208 - val_accuracy: 0.4259
# Epoch 119/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.2028 - accuracy: 0.9333 - val_loss: 4.9558 - val_accuracy: 0.3827
# Epoch 120/150
# 24/24 [==============================] - 59s 3s/step - loss: 0.3093 - accuracy: 0.8827 - val_loss: 3.9598 - val_accuracy: 0.3395
# Epoch 121/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.2055 - accuracy: 0.9307 - val_loss: 4.2400 - val_accuracy: 0.4012
# Epoch 122/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.1364 - accuracy: 0.9467 - val_loss: 4.9152 - val_accuracy: 0.3889
# Epoch 123/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.2240 - accuracy: 0.9147 - val_loss: 5.3883 - val_accuracy: 0.3395
# Epoch 124/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.2333 - accuracy: 0.9147 - val_loss: 4.9308 - val_accuracy: 0.3889
# Epoch 125/150
# 24/24 [==============================] - 60s 2s/step - loss: 0.1334 - accuracy: 0.9493 - val_loss: 5.5609 - val_accuracy: 0.4012
# Epoch 126/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.1269 - accuracy: 0.9600 - val_loss: 4.5623 - val_accuracy: 0.4012
# Epoch 127/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.1371 - accuracy: 0.9493 - val_loss: 4.9300 - val_accuracy: 0.4198
# Epoch 128/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.0492 - accuracy: 0.9893 - val_loss: 6.4546 - val_accuracy: 0.3827
# Epoch 129/150
# 24/24 [==============================] - 59s 3s/step - loss: 0.0518 - accuracy: 0.9893 - val_loss: 7.2992 - val_accuracy: 0.4074
# Epoch 130/150
# 24/24 [==============================] - 60s 2s/step - loss: 0.0745 - accuracy: 0.9787 - val_loss: 8.8427 - val_accuracy: 0.3827
# Epoch 131/150
# 24/24 [==============================] - 62s 3s/step - loss: 0.6771 - accuracy: 0.8027 - val_loss: 3.4182 - val_accuracy: 0.3827
# Epoch 132/150
# 24/24 [==============================] - 60s 2s/step - loss: 0.6941 - accuracy: 0.7387 - val_loss: 2.3037 - val_accuracy: 0.3272
# Epoch 133/150
# 24/24 [==============================] - 58s 2s/step - loss: 0.3498 - accuracy: 0.8933 - val_loss: 3.5676 - val_accuracy: 0.3642
# Epoch 134/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.1704 - accuracy: 0.9467 - val_loss: 5.0414 - val_accuracy: 0.3519
# Epoch 135/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.0943 - accuracy: 0.9627 - val_loss: 5.5022 - val_accuracy: 0.3827
# Epoch 136/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.2211 - accuracy: 0.9360 - val_loss: 4.6340 - val_accuracy: 0.3765
# Epoch 137/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.1771 - accuracy: 0.9467 - val_loss: 5.1553 - val_accuracy: 0.3519
# Epoch 138/150
# 24/24 [==============================] - 58s 2s/step - loss: 0.1726 - accuracy: 0.9307 - val_loss: 5.0730 - val_accuracy: 0.4012
# Epoch 139/150
# 24/24 [==============================] - 59s 2s/step - loss: 0.1021 - accuracy: 0.9680 - val_loss: 5.2388 - val_accuracy: 0.3519
# Epoch 140/150
# 24/24 [==============================] - 60s 2s/step - loss: 0.0997 - accuracy: 0.9600 - val_loss: 6.1181 - val_accuracy: 0.3951
# Epoch 141/150
# 24/24 [==============================] - 61s 3s/step - loss: 0.1161 - accuracy: 0.9680 - val_loss: 5.7253 - val_accuracy: 0.3889
# Epoch 142/150
# 24/24 [==============================] - 62s 3s/step - loss: 0.1105 - accuracy: 0.9600 - val_loss: 6.6845 - val_accuracy: 0.4074
# Epoch 143/150
# 24/24 [==============================] - 65s 3s/step - loss: 0.1041 - accuracy: 0.9653 - val_loss: 5.7075 - val_accuracy: 0.3827
# Epoch 144/150
# 24/24 [==============================] - 63s 3s/step - loss: 0.0968 - accuracy: 0.9707 - val_loss: 5.9567 - val_accuracy: 0.4074
# Epoch 145/150
# 24/24 [==============================] - 62s 3s/step - loss: 0.0574 - accuracy: 0.9733 - val_loss: 6.5481 - val_accuracy: 0.3951
# Epoch 146/150
# 24/24 [==============================] - 62s 3s/step - loss: 0.0368 - accuracy: 0.9920 - val_loss: 7.3516 - val_accuracy: 0.3580
# Epoch 147/150
# 24/24 [==============================] - 62s 3s/step - loss: 0.0142 - accuracy: 0.9947 - val_loss: 8.7186 - val_accuracy: 0.3827
# Epoch 148/150
# 24/24 [==============================] - 62s 3s/step - loss: 0.1782 - accuracy: 0.9627 - val_loss: 7.7865 - val_accuracy: 0.3086
# Epoch 149/150
# 24/24 [==============================] - 62s 3s/step - loss: 0.2619 - accuracy: 0.8987 - val_loss: 5.3329 - val_accuracy: 0.3333
# Epoch 150/150
# 24/24 [==============================] - 62s 3s/step - loss: 0.2325 - accuracy: 0.9227 - val_loss: 4.8686 - val_accuracy: 0.3519

# %% [markdown]
# base_model.trainable=True
# model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.00001),loss=tf.keras.losses.CategoricalCrossentropy(),metrics=['accuracy'])
# history = model.fit(train_ds,epochs=10,validation_data=val_ds)
# df_history_ft =pd.DataFrame(history.history)
# df_history_ft.index = df_history_ft.index+EPOCHS
# df_history = pd.concat([df_history, df_history_ft])

# %%
fig, axs = plt.subplots(nrows=1,ncols=2, figsize=(20,5))

axs[0].plot(df_history.index.values, df_history['loss'], label='Train')
axs[0].plot(df_history.index.values, df_history['val_loss'], label='Test')

axs[1].plot(df_history.index.values, df_history['accuracy'], label='Train')
axs[1].plot(df_history.index.values, df_history['val_accuracy'], label='Test')

axs[0].vlines(EPOCHS-1, min(df_history['loss']), max(df_history['loss']))
axs[1].vlines(EPOCHS-1, 0, 1)

plt.legend()

plt.show()

# %%
model.save('vgg16_without_model.h5')
df_history.to_csv('vgg16_without_train.csv')
